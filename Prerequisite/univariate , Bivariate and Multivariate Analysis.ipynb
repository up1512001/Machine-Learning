# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ## univariate analysis

# %%
df_setosa=df.loc[df['species']=='setosa']

# %%
df_virginica=df.loc[df['species']=='virginica']

# %%
df_versicolor=df.loc[df['species']=='versicolor']

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'r')
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']),'y')
plt.plot(df_versicolor['sepal_length'],np.zeros_like(df_versicolor['sepal_length']),'g')

plt.xlabel('sepal length')
# Out:
# Text(0.5, 0, 'sepal length')

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'o')

# %%
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']),'o')

# %%
plt.plot(df_versicolor['sepal_length'],np.zeros_like(df_versicolor['sepal_length']),'o')

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.FacetGrid(df,hue='species',height=5).map(plt.scatter,'sepal_length','sepal_width').add_legend();

# %%
sns.FacetGrid(df,hue='species',height=5).map(plt.scatter,'sepal_length','sepal_width')

# %%
sns.FacetGrid(df,hue='species',height=5).map(plt.plot,'sepal_length','sepal_width')

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df,hue='species',height=3).add_legend()
