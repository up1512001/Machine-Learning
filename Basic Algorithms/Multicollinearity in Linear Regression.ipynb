# %%
import pandas as pd

# %%
import statsmodels.api as sm

# %%
df_adv = pd.read_csv('E:\Data Sets\Multicollinearity-master\Multicollinearity-master\data\Advertising.csv',index_col=0)

# %%
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
x = df_adv.iloc[:,:-1].values

# %%
y = df_adv.iloc[:,-1].values

# %%
x
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2],
#        [ 66.1,   5.8,  24.2],
#        [214.7,  24. ,   4. ],
#        [ 23.8,  35.1,  65.9],
#        [ 97.5,   7.6,   7.2],
#        [204.1,  32.9,  46. ],
#        [195.4,  47.7,  52.9],
#        [ 67.8,  36.6, 114. ],
#        [281.4,  39.6,  55.8],
#        [ 69.2,  20.5,  18.3],
#        [147.3,  23.9,  19.1],
#        [218.4,  27.7,  53.4],
#        [237.4,   5.1,  23.5],
#        [ 13.2,  15.9,  49.6],
#        [228.3,  16.9,  26.2],
#        [ 62.3,  12.6,  18.3],
#        [262.9,   3.5,  19.5],
#        [142.9,  29.3,  12.6],
#        [240.1,  16.7,  22.9],
#        [248.8,  27.1,  22.9],
#        [ 70.6,  16. ,  40.8],
#        [292.9,  28.3,  43.2],
# ...

# %%
y
# Out:
# array([22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#        17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 12.5,
#         5.6, 15.5,  9.7, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,
#        17.4,  9.5, 12.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 12.9,
#         8.5, 14.9, 10.6, 23.2, 14.8,  9.7, 11.4, 10.7, 22.6, 21.2, 20.2,
#        23.7,  5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 15.7, 14. , 18. ,  9.3,
#         9.5, 13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 11. , 11.8, 12.3, 11.3, 13.6, 21.7, 15.2, 12. , 16. ,
#        12.9, 16.7, 11.2,  7.3, 19.4, 22.2, 11.5, 16.9, 11.7, 15.5, 25.4,
#        17.2, 11.7, 23.8, 14.8, 14.7, 20.7, 19.2,  7.2,  8.7,  5.3, 19.8,
#        13.4, 21.8, 14.1, 15.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,
#         7. , 11.6, 15.2, 19.7, 10.6,  6.6,  8.8, 24.7,  9.7,  1.6, 12.7,
#         5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1,
# ...

# %%
x = sm.add_constant(x)
model = sm.OLS(y,x).fit()

# %%
x
# Out:
# array([[  1. , 230.1,  37.8,  69.2],
#        [  1. ,  44.5,  39.3,  45.1],
#        [  1. ,  17.2,  45.9,  69.3],
#        [  1. , 151.5,  41.3,  58.5],
#        [  1. , 180.8,  10.8,  58.4],
#        [  1. ,   8.7,  48.9,  75. ],
#        [  1. ,  57.5,  32.8,  23.5],
#        [  1. , 120.2,  19.6,  11.6],
#        [  1. ,   8.6,   2.1,   1. ],
#        [  1. , 199.8,   2.6,  21.2],
#        [  1. ,  66.1,   5.8,  24.2],
#        [  1. , 214.7,  24. ,   4. ],
#        [  1. ,  23.8,  35.1,  65.9],
#        [  1. ,  97.5,   7.6,   7.2],
#        [  1. , 204.1,  32.9,  46. ],
#        [  1. , 195.4,  47.7,  52.9],
#        [  1. ,  67.8,  36.6, 114. ],
#        [  1. , 281.4,  39.6,  55.8],
#        [  1. ,  69.2,  20.5,  18.3],
#        [  1. , 147.3,  23.9,  19.1],
#        [  1. , 218.4,  27.7,  53.4],
#        [  1. , 237.4,   5.1,  23.5],
#        [  1. ,  13.2,  15.9,  49.6],
#        [  1. , 228.3,  16.9,  26.2],
#        [  1. ,  62.3,  12.6,  18.3],
# ...

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Wed, 21 Apr 2021   Prob (F-statistic):           1.58e-96
# Time:                        09:43:50   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
model.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.896
# Dependent Variable: y                AIC:                780.3622
# Date:               2021-04-21 09:44 BIC:                793.5555
# No. Observations:   200              Log-Likelihood:     -386.18
# Df Model:           3                F-statistic:        570.3
# Df Residuals:       196              Prob (F-statistic): 1.58e-96
# R-squared:          0.897            Scale:              2.8409
# -------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025   0.975]
# -------------------------------------------------------------------
# const       2.9389     0.3119    9.4223   0.0000    2.3238   3.5540
# x1          0.0458     0.0014   32.8086   0.0000    0.0430   0.0485
# x2          0.1885     0.0086   21.8935   0.0000    0.1715   0.2055
# ...

# %%
import matplotlib.pyplot as plt
df_adv.iloc[:,:-1].corr()
# Out:
#                  TV     radio  newspaper
# TV         1.000000  0.054809   0.056648
# radio      0.054809  1.000000   0.354104
# newspaper  0.056648  0.354104   1.000000

# %%
df_sal = pd.read_csv('E:\Data Sets\Multicollinearity-master\Multicollinearity-master\data\Salary_Data.csv')

# %%
df_sal.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
x = df_sal[['YearsExperience','Age']]
y = df_sal['Salary']

# %%
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     323.9
# Date:                Wed, 21 Apr 2021   Prob (F-statistic):           1.35e-19
# Time:                        09:52:49   Log-Likelihood:                -300.35
# No. Observations:                  30   AIC:                             606.7
# Df Residuals:                      27   BIC:                             610.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
x.iloc[:,1:].corr()
# Out:
#                  YearsExperience       Age
# YearsExperience         1.000000  0.987258
# Age                     0.987258  1.000000

# %% [markdown]
# ## So you can drop Age feature Or You train with whole dataset {Don't care about multicollinearity}

# %% [markdown]
# ### and in first advertising dataset you can drop newspaper feature because it is unnecessary expenditure
